# %% [markdown]
# # <center>**PRÁCTICA 3**<center>

# %% [markdown]
# # <center>AG3<center>

# %%
# Importar los modulos

import pandas as pd
import io
import requests
import seaborn as sns # Visualización 
import timeit
import matplotlib.pyplot as plt # Visualización base

# %%
# Cargar el dataSet


url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
s=requests.get(url).content
titanic=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Información del dataset
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
# Renombrar columnas
titanic.rename(columns={'class':'clase'},inplace=True)
titanic.rename(columns={'fare':'tarifa'},inplace=True)

# Mostrar valores unicos (clases)
titanic.clase.unique()

# Primeras 5 filas
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Añadir columna is_old, is_baby

def is_old_func(row):
  return row['age'] > 60

titanic['is_old'] = titanic.apply(is_old_func, axis='columns')

titanic.eval( ' is_baby = age < 15' , inplace = True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch   tarifa embarked   clase  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# Imprimir dataSet
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  is_old  is_baby
# 0    man        True  NaN  Southampton    no  False   False    False
# 1  woman       False    C    Cherbourg   yes  False   False    False
# 2  woman       False  NaN  Southampton   yes   True   False    False
# 3  woman       False    C  Southampton   yes  False   False    False
# 4    man        True  NaN  Southampton    no   True   False    False

# %%
# Columna class_num

def class_num_func(row):
  Clase={'Third':3,'First':1,'Second':2}
  return Clase[row.clase]

titanic['class_num'] = titanic.apply(class_num_func, axis='columns')

# %%
# Imprimir
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  is_old  is_baby  \
# 0    man        True  NaN  Southampton    no  False   False    False
# 1  woman       False    C    Cherbourg   yes  False   False    False
# 2  woman       False  NaN  Southampton   yes   True   False    False
# 3  woman       False    C  Southampton   yes  False   False    False
# 4    man        True  NaN  Southampton    no   True   False    False
#
#    class_num
# 0          3
# 1          1
# 2          3
# 3          1
# 4          3

# %%
# Query

titanic[(titanic.sex == 'female') & (titanic['clase'].isin(['First','Third'])) & (titanic.age > 45) & (titanic.survived == 0)]
# Out:
#      survived  pclass     sex   age  sibsp  parch   tarifa embarked  clase  \
# 132         0       3  female  47.0      1      0  14.5000        S  Third
# 177         0       1  female  50.0      0      0  28.7125        C  First
# 736         0       3  female  48.0      1      3  34.3750        S  Third
#
#        who  adult_male deck  embark_town alive  alone  is_old  is_baby  \
# 132  woman       False  NaN  Southampton    no  False   False    False
# 177  woman       False    C    Cherbourg    no   True   False    False
# 736  woman       False  NaN  Southampton    no  False   False    False
#
#      class_num
# 132          3
# 177          1
# 736          3

# %%
# Distribución de la variable clase

# Qué clase de pasajeros tenía más el Titanic

sns.countplot(x="pclass", data=titanic) # countplot: contabiliza por clases
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
# Distribucion basado en histogramas por la edad

sns.histplot(titanic.age.dropna(), kde=True)  # 1 param: edad.dropna() para que no se visualicen en el histograma. kde= para visualizar la línea suavizada.
plt.show()

# %%
# Boxplot edad vs sexo

with sns.axes_style(style='ticks'):  # with para controlar algun tipo de sesión.

  ax = sns.catplot(data=titanic, x="sex", y="age", hue="clase", kind="box")  # diagrama de cajas: catplot. con hue: me pinta tres diagramas de cajas por sexo.

  # Los rombos superiores del gráfico son outliers.

# %%
# Hay que tratar los outliers.

# %%
# Distribucion cruzada

sns.jointplot(x="tarifa", y="age", data=titanic)

# %% [markdown]
# Los dos puntos de la derecha pueden ser outliers, o algún camarote valía muy superior -> tienen una media de 35 años aproximadamente.
# Los que han pagado más son los de 20 años.
# Tarifas más baratas, hay una mezcla de edades.

# %%
# Matriz de gráficos
sns.set(font_scale=1)
g = sns.FacetGrid(titanic, row='survived',col='clase')
g.map(sns.histplot, "age", kde=True) # Por cada celda, creo un histrograma. kde: línea suavizada.
plt.show()

# %% [markdown]
# Edad_ eje x. Eje y, contabilizado de pasajeros.
# 1: Pasajeros que no han sobrevivido de tercera.
# La mayoría de los fallecimientos son o personas jóvenes o personas de 20, 30 años.
# 4: Nos fijamos, que tampoco hay personas mayores que sobreviven. 1: sobreviven.

# %%
# Diamagra de dispersión

sns.jointplot(data=titanic, x='age', y='tarifa', kind='reg', color='b')
plt.show()

# %% [markdown]
# Cuanta más edad tengas, más pagas por una habitación.

# %%
# Diagrama de correlaciones

tc = titanic.corr()

sns.heatmap(tc,cmap='coolwarm') # Mapa de calor. 0 no correlacionado. Que columnas están conectadas con otras columnas.
plt.title('titanic.corr()')
# Out:
# <ipython-input-12-3aa8c1d26b79>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tc = titanic.corr()
# Text(0.5, 1.0, 'titanic.corr()')

# %% [markdown]
# Hay datos que no cuadran, ¿Como `is_baby` no relaciona con la `edad`?
# Pues porque no puedes correlacionar con datos en crudo. Hay que procesar, limpieza... y luego correlacionar.
#
# Mejor basarnos en las distribuciones.

# %% [markdown]
# **Diagramas de dispersión de parejas de variables cuantitativas**

# %%
# Define un subconjunto de datos con las variables numéricas
titanic_num = titanic[['survived', 'pclass', 'sibsp','parch', 'tarifa']]

#Hace una matriz de diagramas de dispersión de parejas de variables.
sns.pairplot(titanic_num, hue="survived")
plt.show()

# %% [markdown]
# **Diagramas de dispersión de parejas de variables cuantitativas**

# %% [markdown]
# ## Ampliación de la Práctica
#
# ####**Diagramas de distribución de clase/edad y supervivientes**

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch   tarifa embarked   clase  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# Matriz de gráficos
sns.set(font_scale=1)
g = sns.FacetGrid(titanic, row='sex',col='pclass', hue='survived')
g.map(sns.histplot, "age", kde=False).add_legend() # Por cada celda, creo uun histrograma. kde: línea suavizada.
g.set_ylabels('')
g.set(ylim=(0,70), yticks=[0,20,40,60])


plt.show()
